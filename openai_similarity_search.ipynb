# %%
import os
import time
import pandas as pd
import numpy as np
import openai
from tqdm import tqdm
tqdm.pandas()

# %%
openai.api_key = os.getenv("OPENAI_API_KEY", None)

# %%
df_tagged_imgs = pd.read_csv("./tagged_dataset/final-tags.csv")
df_tagged_imgs = df_tagged_imgs.loc[:, ~df_tagged_imgs.columns.str.contains('^Unnamed')]
df_tagged_imgs.tail(2)
# Out:
#                                     image_name  \
# 1308  280678d5-383f-450e-856e-08e2c11288e7.png
# 1309  891a97af-592f-4837-bd62-693793401ff7.png
#
#                                              image_path  \
# 1308  /media/pixis/pixis/Ravi_workspace/Entity-taggi...
# 1309  /media/pixis/pixis/Ravi_workspace/Entity-taggi...
#
#                                                    tags  \
# 1308  ['circle', 'cotton candy', 'cube', 'green', 'h...
# 1309              ['crack', 'marble', 'stone', 'white']
#
#                                           extended_tags background_category
# 1308  ['minimalistic background', 'top view of stone...        MINIMALISTIC
# 1309  ['minimalistic background', 'kept on old shabb...        MINIMALISTIC

# %%
import ast
def get_tags_embeddings(tags_list):
    tags_list = ast.literal_eval(tags_list)
    tag_line = ', '.join(tags_list)
    embeddings = []
    response = openai.embeddings.create(input=tag_line, model="text-embedding-3-large")
    embeddings = response.data[0].embedding
    return embeddings

start_time = time.time()
df_tagged_imgs["tag_embeddings"] = df_tagged_imgs["extended_tags"].progress_apply(get_tags_embeddings)
end_time = time.time()
execution_time = end_time - start_time
# print(execution_time)
# Out:
# 100%|██████████| 1310/1310 [17:07<00:00,  1.28it/s]

# %%
df_tagged_imgs.to_csv("./tagged_dataset/embedded_tags.csv")

# %%
from PIL import Image
import numpy as np


def get_numpy_array(image_path):
    img = Image.open(image_path)
    return img

# %%
df_tagged_imgs["numpy_arr_img"] = df_tagged_imgs["image_path"].progress_apply(get_numpy_array)
# Out:
# 100%|██████████| 1310/1310 [00:18<00:00, 71.74it/s]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

def get_top_n_plots(top_image_arrays):
    images_per_row = 3
    total_images = len(top_image_arrays)
    rows = (total_images + images_per_row - 1) // images_per_row

    # Create a figure with the specified size
    fig, axes = plt.subplots(nrows=rows, ncols=images_per_row, figsize=(12, rows * 3))

    # Loop through the top_image_arrays and plot them
    for idx, img in enumerate(top_image_arrays):
        row = idx // images_per_row
        col = idx % images_per_row
        axes[row, col].imshow(img)
        axes[row, col].axis('off')

    # Hide any empty subplots
    for i in range(total_images, rows * images_per_row):
        row = i // images_per_row
        col = i % images_per_row
        axes[row, col].axis('off')

    # Adjust layout and display the plot
    plt.tight_layout()
    plt.show()


def get_top_n_similar_embeddings(new_embedding, tags_df, top_n=10):
    # Ensure the embeddings are in the correct format
    tag_embeddings = np.array(tags_df['tag_embeddings'].tolist())
    
    # Calculate the cosine similarity between the new embedding and the embeddings in the dataframe
    similarities = cosine_similarity([new_embedding], tag_embeddings)[0]
    
    top_indices = np.argsort(similarities)[-top_n:][::-1]
    
    top_similarities = similarities[top_indices]
    top_embeddings = tags_df.iloc[top_indices]
    
    # Get the image file paths of the top_n most similar embeddings
    top_image_arrays = top_embeddings['numpy_arr_img'].tolist()
    
    return top_image_arrays, top_similarities

def embed_query(input_query):
    input_query = ', '.join(input_query)
    response = openai.embeddings.create(input=input_query, model="text-embedding-3-large")
    embeddings = response.data[0].embedding
    return embeddings

# %%
df_tagged_imgs = df_tagged_imgs.loc[:, ~df_tagged_imgs.columns.str.contains('^Unnamed')]

# %%
query = ["sea"]
curr_embbedding = embed_query(query)
print(curr_embbedding)
# top_image_arrays, top_similarities = get_top_n_similar_embeddings(curr_embbedding, df_tagged_imgs, top_n=9)
# get_top_n_plots(top_image_arrays)
# Out:
# [-0.024967990815639496, 0.000279679661616683, 0.021536072716116905, 2.3291264369618148e-05, 0.000540172855835408, 0.019725656136870384, 0.03787703812122345, 0.012192754074931145, -0.06819756329059601, 0.023220546543598175, -0.014546294696629047, 0.04385928064584732, 0.006722151301801205, -0.012531223706901073, -0.01176770031452179, 0.005281690042465925, -0.018182868137955666, -0.010642094537615776, -0.022307466715574265, -0.01185428537428379, 0.0058995927684009075, -0.0033728827256709337, 0.012137655168771744, 0.014774564653635025, 0.0035696669947355986, 0.020733192563056946, 0.03302827477455139, 0.027612771838903427, -0.022590836510062218, 0.008461724035441875, 0.01697067730128765, 0.0678827092051506, -0.010287882760167122, -0.0028927288949489594, -0.03727881610393524, 0.04294620454311371, -0.007918599992990494, -0.010886106640100479, 0.006013727746903896, -0.040899645537137985, -0.006777250673621893, -0.008217711932957172, -0.0104846665635705, 0.04436304792761803, -0.014853278174996376, 0.019930312409996986, -0.005061291623860598, 0.01593165658414364, -0.001752364099957049, 0.0023358294274657965, -0.04952666908502579, 0.00891039241105318, -0.022527864202857018, 0.030603893101215363, -0.05972796678543091, 0.01608908362686634, 0.06630843132734299, 0.025566214695572853, -0.030903004109859467, -0.0036109916400164366, -0.028273966163396835, -0.06190046668052673, 0.004592945333570242, 0.01693919114768505, -0.00795008521527052, 0.0022846655920147896, 0.03617682307958603, -0.003276458475738764, -0.019993282854557037, 0.028856446966528893, -0.008233455009758472, -0.03444512188434601, 0.016498394310474396, 0.04795239493250847, 0.01944228820502758, 0.009028462693095207, 0.04716525599360466, -0.0026329737156629562, -0.04102558642625809, 0.0003780717961490154, 0.024873534217476845, -0.0028002404142171144, 0.015309817157685757, 0.011484330520033836, -0.0023161510471254587, -0.009973027743399143, -0.003221358871087432, -0.084381103515625, -0.0016087115509435534, 0.004758243914693594, 0.002182337688282132, 0.029187045991420746, -0.006147541105747223, 0.022590836510062218, 0.031548455357551575, 0.018828321248292923, -0.017285531386733055, -0.00672608707100153, 0.0033984645269811153, 0.02851010672748089, -0.01433376781642437, -0.018324552103877068, -0.0014680108288303018, -0.0084381103515625, -0.04149787127971649, 0.051195401698350906, -0.025550471618771553, 0.04801536723971367, -0.02351965755224228, -0.04149787127971649, 0.01098056323826313, 0.015073676593601704, -0.010342981666326523, -0.026337608695030212, 0.0011748021934181452, -0.044237107038497925, -0.0336265005171299, 0.06486009806394577, -0.0002526218304410577, -0.0007290857611224055, -0.024653134867548943, -0.03941982984542847, 0.015734871849417686, -0.029801012948155403, 0.03879011794924736, -0.008721479214727879, -0.011098633520305157, -0.022323209792375565, 0.018371781334280968, -0.02351965755224228, -0.00734792510047555, -0.014262924902141094, -0.015105161815881729, 0.013688314706087112, -0.0017464605625718832, 0.010366596281528473, -0.018025441095232964, 0.027187716215848923, 0.014239311218261719, -0.015309817157685757, -0.023220546543598175, -0.001870434614829719, -0.022606579586863518, -0.013704057782888412, 0.009839214384555817, 0.01175195723772049, -0.0008476483053527772, -0.003471274860203266, -0.025046704337000847, 0.00014180767175275832, 0.024700364097952843, -0.019552486017346382, 0.018859805539250374, -0.024637391790747643, -0.007257404271513224, 0.005588673520833254, 0.03642870858311653, 0.013759157620370388, 0.034256208688020706, 0.007808400318026543, -0.010020256042480469, -0.060168761759996414, 0.012814592570066452, -0.03731030225753784, -0.01613631099462509, -0.00891039241105318, 0.04562246799468994, -0.04625217989087105, 0.006899257190525532, 0.029281502589583397, 0.002739237155765295, -0.0053682755678892136, 0.013357717543840408, 0.008076027035713196, 0.014286539517343044, -0.02374005690217018, 0.04042736440896988, 0.02701454609632492, -0.029155559837818146, 0.03 ...

# %%
df_tagged_imgs.to_csv("./tagged_dataset/pil_embedded_tags.csv")

# %%
df_tagged_imgs = pd.read_csv("./tagged_dataset/pil_embedded_tags.csv")

# %%
print(type(df_tagged_imgs["tag_embeddings"]))
temp = df_tagged_imgs["tag_embeddings"].iloc[0]
print(type(temp))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'str'>
